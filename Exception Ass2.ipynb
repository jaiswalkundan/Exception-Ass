# %%
Q1. Explain why we have to use the Exception class while creating a Custom Exception.
Note: Here Exception class refers to the base class for all the exceptions.

# %% [markdown]
# when creating a custom exception in a programming language using the Exception class as the base class is essential for few reasons.
# Firstly it ensure that your custom exception inherit form a well established and standardized exception hierarchy.

# %%
Q2. Write a python program to print Python Exception Hierarchy.

# %%
def print_exception_hierarchy(exception_class,indent=0):
    print(' ' * indent+str(exception_class))
    for subclass in exception_class.__subclasses__():
        print_exception_hierarchy(subclass,indent + 2)
print_exception_hierarchy(Exception)
# Out:
# <class 'Exception'>
#   <class 'TypeError'>
#     <class 'decimal.FloatOperation'>
#     <class 'email.errors.MultipartConversionError'>
#   <class 'StopAsyncIteration'>
#   <class 'StopIteration'>
#   <class 'ImportError'>
#     <class 'ModuleNotFoundError'>
#     <class 'zipimport.ZipImportError'>
#   <class 'OSError'>
#     <class 'ConnectionError'>
#       <class 'BrokenPipeError'>
#       <class 'ConnectionAbortedError'>
#       <class 'ConnectionRefusedError'>
#       <class 'ConnectionResetError'>
#         <class 'http.client.RemoteDisconnected'>
#     <class 'BlockingIOError'>
#     <class 'ChildProcessError'>
#     <class 'FileExistsError'>
#     <class 'FileNotFoundError'>
#     <class 'IsADirectoryError'>
#     <class 'NotADirectoryError'>
#     <class 'InterruptedError'>
#       <class 'zmq.error.InterruptedSystemCall'>
#     <class 'PermissionError'>
#     <class 'ProcessLookupError'>
#     <class 'TimeoutError'>
#     <class 'io.UnsupportedOperation'>
# ...

# %%
Q3. What errors are defined in the ArithmeticError class? Explain any two with an example.

# %%
1.ZerodivisionError

# %%
numerator=10
denominator=0
try:
    result = numerator/denominator
except ZeroDivisionError as e:
    print(f"Error:{e}")
# Out:
# Error:division by zero

# %%
2.overflowError.

# %%
try:
    result = 2**1024
except OverflowError as e:
    print(f"Error: {e}")

# %%
Q4. Why LookupError class is used? Explain with an example KeyError and IndexError.

# %%
1.keyError.

# %%
my_dict={'appel':3,'banana':5,'orange':2}
try:
    quantity_of_grapes =my_dict['grapes']
except KeyError as e:
    print(f"KeyError:{e}")

# %%
my_list=[1,2,3]
try:
    value = my_list[4]
except IndexError as e:
    print(f"IndexError:{e}")
# Out:
# IndexError:list index out of range

# %%
Q5. Explain ImportError. What is ModuleNotFoundError?

# %% [markdown]
# ImportError is generic exception raised when an import statement fails to find or load a module
#
# ModuleNotfoundError is a specific subclass of importError intoduced in pythonit is raised when the requested module cannot be found this typically happens if the modul is not installed or the specified module name is incorrect

# %%
Q6. List down some best practices for exception handling in python.

# %%
1 use specific Exception
2.Avoid Bare Excepts
3.Try Except Blocks
4.Handle Exception Locally
5.Logging
6.Cleanup
7.Custom
8.Fail Fast
9.Avoid hinding Error
10.Graceful Degradation
